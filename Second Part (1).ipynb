# %% [markdown]
# # Opening Italian Restaurants in Houston City
#
# ### Introduction
#
# The main objective of this project is to analyze the areas in Houston city where Italian Restaurants are available in order to select the optimum location for a new restaurant. The selection will be based on teh nighborhood with minimum number of restaurants. The analysis will be shared with stakeholders to confirm the location selection.
#
# ### Data Collection
#
# #### Geographical Coordinates
# The geographical coordinates for Houston will be gathered from Python GeoPy library in python.
#
# #### Neighborhoods information:
# The data of the neighborhoods in Houston was collected from was scraped from https://en.wikipedia.org/wiki/List_of_Houston_neighborhoods. The data will be converted into pandas data frame.
#
# #### Venue information:
# The venue data will collected from Foursquare API.

# %%
import numpy as np
import pandas as pd
import json
# !pip install geopy
# !pip install geocoder
from geopy.geocoders import Nominatim
import geocoder
import requests
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
# !pip install folium
import folium
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.io.json import json_normalize
from sklearn.metrics import silhouette_score

# %matplotlib notebook

print('Done')
# Out:
# Requirement already satisfied: geopy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geopy) (1.50)
# Requirement already satisfied: geocoder in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (1.38.1)
# Requirement already satisfied: ratelim in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geocoder) (1.15.0)
# Requirement already satisfied: future in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geocoder) (2.24.0)
# Requirement already satisfied: click in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geocoder) (7.1.2)
# Requirement already satisfied: decorator in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from ratelim->geocoder) (4.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->geocoder) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->geocoder) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->geocoder) (2.9)
# Requirement already satisfied: folium in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (0.12.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.11.2)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.24.0)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (0.4.2)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (1.18.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Done

# %% [markdown]
# Reteriving the data of the Neighborhoods and identify the different location Values

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_Houston_neighborhoods')[0]
df.rename(columns={'Name': 'Neighborhood', 'Location relative to Downtown Houston':'Location'}, inplace=True)
df.pop('Approximate boundaries')
df.pop('#')
df.head(10)
# Out:
#                      Neighborhood   Location
# 0                     Willowbrook  Northwest
# 1             Greater Greenspoint      North
# 2                      Carverdale  Northwest
# 3  Fairbanks / Northwest Crossing  Northwest
# 4                  Greater Inwood  Northwest
# 5                      Acres Home  Northwest
# 6                   Hidden Valley      North
# 7                      Westbranch       West
# 8              Addicks / Park Ten       West
# 9              Spring Branch West       West

# %%
df['Location'].value_counts()
# Out:
# Southwest    15
# Southeast    14
# Northwest    12
# West         12
# Northeast    11
# South        11
# East          6
# North         6
# —             1
# Name: Location, dtype: int64

# %% [markdown]
# Adjusting the location data to reflect the Downtown

# %%
for index in df.index:
    if df.loc[index,'Neighborhood']=='Downtown':
        df.loc[index,'Location'] = 'Downtown'

# %%
df['Location'].value_counts()
# Out:
# Southwest    15
# Southeast    14
# Northwest    12
# West         12
# Northeast    11
# South        11
# East          6
# North         6
# Downtown      1
# Name: Location, dtype: int64

# %%
df['Latitude'] = None
df['Longitude'] = None

for i, neigh in enumerate(df['Neighborhood']):
    lat_lng_coords = None
    
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, Houston'.format(neigh))
        lat_lng_coords = g.latlng
    
    if lat_lng_coords:
        latitude = lat_lng_coords[0]
        longitude = lat_lng_coords[1]
    
    df.loc[i, 'Latitude'] = latitude
    df.loc[i, 'Longitude'] = longitude

df.head(10)
# Out:
#                      Neighborhood   Location Latitude Longitude
# 0                     Willowbrook  Northwest  29.9524  -95.5446
# 1             Greater Greenspoint      North  29.9397  -95.4075
# 2                      Carverdale  Northwest  29.8496  -95.5424
# 3  Fairbanks / Northwest Crossing  Northwest  29.8494  -95.5109
# 4                  Greater Inwood  Northwest  29.8698  -95.4804
# 5                      Acres Home  Northwest  29.8705  -95.4354
# 6                   Hidden Valley      North  29.8885  -95.4146
# 7                      Westbranch       West  29.8394  -95.5536
# 8              Addicks / Park Ten       West  29.8143  -95.6159
# 9              Spring Branch West       West  29.8011  -95.5493

# %% [markdown]
# ### Now we will visualize the Data

# %%
neighborhood_Houston = df.groupby('Location')['Neighborhood'].nunique()
neighborhood_Houston
# Out:
# Location
# Downtown      1
# East          6
# North         6
# Northeast    11
# Northwest    12
# South        11
# Southeast    14
# Southwest    15
# West         12
# Name: Neighborhood, dtype: int64

# %%
fig = plt.figure(figsize=(14,8))

ax = neighborhood_Houston.plot(kind='barh', color='lightcoral')
ax.set_title('Neighborhoods Grouped by Location in Houston', fontsize=18)
ax.set_xlabel('Number of Neighborhoods', fontsize=14)
ax.set_ylabel('Location', fontsize=14)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.tick_params(which='major', left=False)

fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1400">

# %%
address = 'Houston, USA'
geolocator = Nominatim(user_agent='daifmoh@gmail.com')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Houston are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Houston are 29.7589382, -95.3676974.

# %%
map_Houston = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, location, neighborhood in zip(df['Latitude'], df['Longitude'], df['Location'], df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, location)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='Blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Houston)  
    
map_Houston
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d3f956640f6340388ed4184e0f525d19%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d3f956640f6340388ed4184e0f525d19%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_d3f956640f6340388ed4184e0f525d19%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_d3f956640f6340388ed4184e0f525d19%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B29.7589382%2C%20-95.3676974%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ##### The venue Analysis will be done from Houston Downtown

# %%
neighborhood_name = df.loc[60, 'Neighborhood']
neighborhood_lat = df.loc[60, 'Latitude']
neighborhood_long = df.loc[60, 'Longitude']

print("The neighborhood is {} and it's Geographical coordinates are {} latitude and {} longitude".format(neighborhood_name,neighborhood_lat, neighborhood_long))
# Out:
# The neighborhood is Downtown and it's Geographical coordinates are 29.756260000000054 latitude and -95.35655999999994 longitude

# %%
CLIENT_ID = 'GTB2I3BTPHA0LFVNR1PXABL4A4LICUJ1H1JU3HI1UWRIVDRM' # my Foursquare ID
CLIENT_SECRET = 'T3ECK55FTGRIWW0IQGCHEDUDWN2VXDSYWSLEK01CRT33KSSB' # my Foursquare Secret
ACCESS_TOKEN = '9d96b09ba0c291a9b2bcf9bc51ab810775396a97' # my FourSquare Access Token
VERSION = '20180604'
LIMIT = 100
print('My credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# My credentails:
# CLIENT_ID: GTB2I3BTPHA0LFVNR1PXABL4A4LICUJ1H1JU3HI1UWRIVDRM
# CLIENT_SECRET:T3ECK55FTGRIWW0IQGCHEDUDWN2VXDSYWSLEK01CRT33KSSB

# %%
LIMIT = 100
radius = 5000

url = 'https://api.foursquare.com/v2/venues/explore?client_id=GTB2I3BTPHA0LFVNR1PXABL4A4LICUJ1H1JU3HI1UWRIVDRM&client_secret=T3ECK55FTGRIWW0IQGCHEDUDWN2VXDSYWSLEK01CRT33KSSB&ll=29.756260000000054,-95.35655999999994&vauth_token=9d96b09ba0c291a9b2bcf9bc51ab810775396a97&v=20180604&query=Italian%20Restaurant&radius=5000&limit=100'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_lat, 
    neighborhood_long, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=GTB2I3BTPHA0LFVNR1PXABL4A4LICUJ1H1JU3HI1UWRIVDRM&client_secret=T3ECK55FTGRIWW0IQGCHEDUDWN2VXDSYWSLEK01CRT33KSSB&ll=29.756260000000054,-95.35655999999994&vauth_token=9d96b09ba0c291a9b2bcf9bc51ab810775396a97&v=20180604&query=Italian%20Restaurant&radius=5000&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '6005f06ddbd00c6111ef7858'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'},
#     {'name': '$-$$$$', 'key': 'price'}]},
#   'headerLocation': 'Houston',
#   'headerFullLocation': 'Houston',
#   'headerLocationGranularity': 'city',
#   'query': 'italian restaurant',
#   'totalResults': 45,
#   'suggestedBounds': {'ne': {'lat': 29.8012600450001,
#     'lng': -95.30482204634153},
#    'sw': {'lat': 29.71125995500001, 'lng': -95.40829795365836}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b510fe4f964a520554027e3',
#        'name': 'Perbacco',
#        'location': {'address': '700 Milam St',
#         'lat': 29.760257437720647,
#         'lng': -95.36477339516325,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.760257437720647,
#           'lng': -95.36477339516325},
#          {'label': 'entrance', 'lat': 29.760076, 'lng': -95.365164}],
#         'distance': 909,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['700 Milam St',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1914930',
#         'url': 'https://www.grubhub.com/restaurant/perbacco-700-milam-street-houston/1914930?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1914930',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b510fe4f964a520554027e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5815e4be38fab8bf7b564739',
#        'name': 'Grotto Downtown',
#        'location': {'address': '1001 Avenida de las Americas Ste A',
#         'lat': 29.7539178,
#         'lng': -95.3571966,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.7539178,
#           'lng': -95.3571966}],
#         'distance': 267,
#         'postalCode': '77010',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1001 Avenida de las Americas Ste A',
#          'Houston, TX 77010',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2046170',
#         'url': 'https://www.grubhub.com/restaurant/grotto-ristorante-1001-avenida-de-las-americas-houston/2046170?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2046170',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5815e4be38fab8bf7b564739-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7c8437f964a5203b982fe3',
#        'name': 'Quattro',
#        'location': {'address': '1300 Lamar St',
#         'crossStreet': 'Austin St',
#         'lat': 29.754122193587296,
#         'lng': -95.36246896887286,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.754122193587296,
#           'lng': -95.36246896887286}],
#         'distance': 618,
#         'postalCode': '77010',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1300 Lamar St (Austin St)',
#          'Houston, TX 77010',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7c8437f964a5203b982fe3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58a3b9ed51666a278d92af9e',
#        'name': 'Potente',
#        'location': {'address': '1515 Texas St',
#         'crossStreet': 'Crawford St.',
#         'lat': 29.757237886603125,
#         'lng': -95.35744749007415,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.757237886603125,
#           'lng': -95.35744749007415}],
#         'distance': 138,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1515 Texas St (Crawford St.)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1570511',
#         'url': 'https://www.grubhub.com/restaurant/potente-1515-texas-avenue-houston/1570511?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1570511',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58a3b9ed51666a278d92af9e-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b11cb7ff964a520ca8423e3',
#        'name': "Birraporetti's",
#        'location': {'address': '500 Louisiana St',
#         'crossStreet': 'Prairie St',
#         'lat': 29.762461731403604,
#         'lng': -95.36466977857937,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.762461731403604,
#           'lng': -95.36466977857937},
#          {'label': 'entrance', 'lat': 29.762093, 'lng': -95.364847}],
#         'distance': 1044,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['500 Louisiana St (Prairie St)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '559702',
#         'url': 'https://www.grubhub.com/restaurant/birraporettis-restaurant-500-louisiana-st-houston/559702?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=559702',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b11cb7ff964a520ca8423e3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55f42dfc498e7cc71a364d3a',
#        'name': 'Your Pie',
#        'location': {'address': '1625 Main St',
#         'lat': 29.75177,
#         'lng': -95.3686,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75177,
#           'lng': -95.3686}],
#         'distance': 1266,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1625 Main St',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '556949',
#         'url': 'https://www.grubhub.com/restaurant/your-pie-1625-main-st-houston/556949?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=556949',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '149480203'}},
#       'referralId': 'e-0-55f42dfc498e7cc71a364d3a-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f316bbee4b08a0e6d7dbf3d',
#        'name': 'Brooklyn Meatball Company',
#        'location': {'address': '930 Main St Ste T240C',
#         'crossStreet': 'Tunnel @ Travis & McKinney',
#         'lat': 29.75732460146048,
#         'lng': -95.36526623748942,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75732460146048,
#           'lng': -95.36526623748942}],
#         'distance': 849,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['930 Main St Ste T240C (Tunnel @ Travis & McKinney)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f316bbee4b08a0e6d7dbf3d-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a6f3427f964a5209ad51fe3',
#        'name': "Mandola's Deli",
#        'location': {'address': '4105 Leeland St',
#         'crossStreet': 'at Cullen',
#         'lat': 29.73745357701867,
#         'lng': -95.33958704477517,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.73745357701867,
#           'lng': -95.33958704477517},
#          {'label': 'entrance', 'lat': 29.737444, 'lng': -95.339466}],
#         'distance': 2659,
#         'postalCode': '77023',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['4105 Leeland St (at Cullen)',
#          'Houston, TX 77023',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2163359',
#         'url': 'https://www.grubhub.com/restaurant/mandolas-deli-4105-leeland-street-houston/2163359?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2163359',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '46553807'}},
#       'referralId': 'e-0-4a6f3427f964a5209ad51fe3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b3bf596f964a520437f25e3',
#        'name': "Luigi's Pizzeria",
#        'location': {'address': '3700 Almeda Rd',
#         'lat': 29.73544975323939,
#         'lng': -95.37464012641908,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.73544975323939,
#           'lng': -95.37464012641908},
#          {'label': 'entrance', 'lat': 29.735378, 'lng': -95.374611}],
#         'distance': 2901,
#         'postalCode': '77004',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['3700 Almeda Rd',
#          'Houston, TX 77004',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b3bf596f964a520437f25e3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5807b8d338faaedf9e01192b',
#        'name': 'Osso & Kristalla',
#        'location': {'address': '1515 Texas St',
#         'crossStreet': 'Crawford',
#         'lat': 29.7574509,
#         'lng': -95.3579026,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.7574509,
#           'lng': -95.3579026},
#          {'label': 'entrance', 'lat': 29.757192, 'lng': -95.357637}],
#         'distance': 185,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1515 Texas St (Crawford)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1550610',
#         'url': 'https://www.grubhub.com/restaurant/osso--kristalla-1515-texas-avenue-houston/1550610?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1550610',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '451571137'}},
#       'referralId': 'e-0-5807b8d338faaedf9e01192b-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5601496e498e47bc11be7b51',
#        'name': 'Bistecca Ristorante',
#        'location': {'address': '224 Westheimer Rd',
#         'lat': 29.744861,
#         'lng': -95.38399,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.744861,
#           'lng': -95.38399}],
#         'distance': 2939,
#         'postalCode': '77006',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['224 Westheimer Rd',
#          'Houston, TX 77006',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5601496e498e47bc11be7b51-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d87abf1a3b6ca00082da8ef',
#        'name': 'Postino',
#        'location': {'address': '805 Pacific St',
#         'crossStreet': 'Pacific',
#         'lat': 29.746786,
#         'lng': -95.389779,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.746786,
#           'lng': -95.389779}],
#         'distance': 3379,
#         'postalCode': '77006',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['805 Pacific St (Pacific)',
#          'Houston, TX 77006',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2045125',
#         'url': 'https://www.grubhub.com/restaurant/postino---montrose-805-pacific-street-houston/2045125?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2045125',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5d87abf1a3b6ca00082da8ef-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55bd51d8498ef6424c69d787',
#        'name': 'Vinoteca Poscol',
#        'location': {'address': '608 Westheimer Rd',
#         'lat': 29.744611284536187,
#         'lng': -95.38917437436228,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.744611284536187,
#           'lng': -95.38917437436228}],
#         'distance': 3408,
#         'postalCode': '77006',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['608 Westheimer Rd',
#          'Houston, TX 77006',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1562726',
#         'url': 'https://www.grubhub.com/restaurant/poscol-608-westheimer-road-houston/1562726?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1562726',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55bd51d8498ef6424c69d787-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5921daf964a5203b7e28e3',
#        'name': 'Sorrento Ristorante',
#        'location': {'address': '415 Westheimer Rd',
#         'crossStreet': 'Whitney St',
#         'lat': 29.744432669365846,
#         'lng': -95.38704207685616,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.744432669365846,
#           'lng': -95.38704207685616}],
#         'distance': 3226,
#         'postalCode': '77006',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['415 Westheimer Rd (Whitney St)',
#          'Houston, TX 77006',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1561653',
#         'url': 'https://www.grubhub.com/restaurant/sorrento-ristorante-italiano-415-westheimer-road-houston/1561653?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1561653',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5921daf964a5203b7e28e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4acd3b3ef964a52083cb20e3',
#        'name': "Damian's Cucina Italiana",
#        'location': {'address': '3011 Smith St',
#         'lat': 29.74447832449234,
#         'lng': -95.37983685056496,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.74447832449234,
#           'lng': -95.37983685056496},
#          {'label': 'entrance', 'lat': 29.744385, 'lng': -95.379814}],
#         'distance': 2604,
#         'postalCode': '77006',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['3011 Smith St',
#          'Houston, TX 77006',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '562058926'}},
#       'referralId': 'e-0-4acd3b3ef964a52083cb20e3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a4eb589f964a520f1ae1fe3',
#        'name': 'Da Marco',
#        'location': {'address': '1520 Westheimer Rd',
#         'crossStreet': 'btwn Ridgewood & Windsor',
#         'lat': 29.74305917996723,
#         'lng': -95.39790640758915,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.74305917996723,
#           'lng': -95.39790640758915}],
#         'distance': 4257,
#         'postalCode': '77006',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1520 Westheimer Rd (btwn Ridgewood & Windsor)',
#          'Houston, TX 77006',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a4eb589f964a520f1ae1fe3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51029a24e4b0af41981e6b73',
#        'name': 'Coltivare Pizza & Garden',
#        'location': {'address': '3320 White Oak Dr',
#         'crossStreet': 'Arlington St',
#         'lat': 29.78162907500437,
#         'lng': -95.39393573471376,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.78162907500437,
#           'lng': -95.39393573471376},
#          {'label': 'entrance', 'lat': 29.781619, 'lng': -95.393816}],
#         'distance': 4584,
#         'postalCode': '77007',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['3320 White Oak Dr (Arlington St)',
#          'Houston, TX 77007',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51029a24e4b0af41981e6b73-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba416c2f964a520368038e3',
#        'name': "Riva's Italian Restaurant",
#        'location': {'address': '1117 Missouri St',
#         'lat': 29.746124831542097,
#         'lng': -95.39246867513997,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.746124831542097,
#           'lng': -95.39246867513997},
#          {'label': 'entrance', 'lat': 29.74621, 'lng': -95.392552}],
#         'distance': 3649,
#         'postalCode': '77006',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1117 Missouri St',
#          'Houston, TX 77006',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1912166',
#         'url': 'https://www.grubhub.com/restaurant/rivas-italian-restaurant-1117-missouri-street-houston/1912166?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1912166',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba416c2f964a520368038e3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bfc2031a118a593b6006eb6',
#        'name': "Nino's",
#        'location': {'address': '2817 W Dallas St',
#         'crossStreet': 'btwn Waugh & Montrose',
#         'lat': 29.757236056087628,
#         'lng': -95.39525254250077,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.757236056087628,
#           'lng': -95.39525254250077}],
#         'distance': 3740,
#         'postalCode': '77019',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['2817 W Dallas St (btwn Waugh & Montrose)',
#          'Houston, TX 77019',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1553176',
#         'url': 'https://www.grubhub.com/restaurant/ninos-2817-west-dallas-street-houston/1553176?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1553176',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bfc2031a118a593b6006eb6-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf4793794af2d7fd3aa3a72',
#        'name': "Romano's Pizza",
#        'location': {'address': '1528 W Gray St',
#         'lat': 29.754156151314447,
#         'lng': -95.40026532217333,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.754156151314447,
#           'lng': -95.40026532217333},
#          {'label': 'entrance', 'lat': 29.754885, 'lng': -95.399655}],
#         'distance': 4230,
#         'postalCode': '77019',
#         'cc': 'US',
#         'neighborhood': 'Neartown - Montrose',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1528 W Gray St',
#          'Houston, TX 77019',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf4793794af2d7fd3aa3a72-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1768fef964a52052c523e3',
#        'name': 'Grappino Di Nino',
#        'location': {'address': '2817 W Dallas St',
#         'crossStreet': 'Btwn Waugh & Montrose',
#         'lat': 29.756788256604136,
#         'lng': -95.3952317269909,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.756788256604136,
#           'lng': -95.3952317269909}],
#         'distance': 3737,
#         'postalCode': '77019',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['2817 W Dallas St (Btwn Waugh & Montrose)',
#          'Houston, TX 77019',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1553832',
#         'url': 'https://www.grubhub.com/restaurant/grappino-di-nino-2817-west-dallas-street-houston/1553832?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1553832',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1768fef964a52052c523e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb53693ef159c74397774f7',
#        'name': "Vincent's Restaurant",
#        'location': {'address': '2701 W Dallas St',
#         'crossStreet': 'Btwn Waugh & Montrose',
#         'lat': 29.757243859882408,
#         'lng': -95.39500462677692,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.757243859882408,
#           'lng': -95.39500462677692}],
#         'distance': 3716,
#         'postalCode': '77019',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['2701 W Dallas St (Btwn Waugh & Montrose)',
#          'Houston, TX 77019',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb53693ef159c74397774f7-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bafb6e9f964a520431a3ce3',
#        'name': 'Pronto Cucinino',
#        'location': {'address': '1401 Montrose Blvd',
#         'crossStreet': 'W Gray St',
#         'lat': 29.7547684517546,
#         'lng': -95.39205690377517,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.7547684517546,
#           'lng': -95.39205690377517},
#          {'label': 'entrance', 'lat': 29.754756, 'lng': -95.39194}],
#         'distance': 3434,
#         'postalCode': '77019',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1401 Montrose Blvd (W Gray St)',
#          'Houston, TX 77019',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1915092',
#         'url': 'https://www.grubhub.com/restaurant/pronto-cucinino-1401-montrose-boulevard-houston/1915092?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1915092',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bafb6e9f964a520431a3ce3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b044d96f964a5201c5322e3',
#        'name': "Patrenella's Ristorante Italiano",
#        'location': {'address': '813 Jackson Hill St',
#         'lat': 29.76913186290338,
#         'lng': -95.40203240018998,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.76913186290338,
#           'lng': -95.40203240018998},
#          {'label': 'entrance', 'lat': 29.769143, 'lng': -95.40201}],
#         'distance': 4621,
#         'postalCode': '77007',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['813 Jackson Hill St',
#          'Houston, TX 77007',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b044d96f964a5201c5322e3-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53459348498e855d92019446',
#        'name': "Pizaro's Pizza Napoletana II",
#        'location': {'address': '1020 W Gray St Ste 400',
#         'crossStreet': 'Montrose Blvd.',
#         'lat': 29.75360573452095,
#         'lng': -95.39191895184278,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75360573452095,
#           'lng': -95.39191895184278},
#          {'label': 'entrance', 'lat': 29.753451, 'lng': -95.391696}],
#         'distance': 3429,
#         'postalCode': '77019',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1020 W Gray St Ste 400 (Montrose Blvd.)',
#          'Houston, TX 77019',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2318200',
#         'url': 'https://www.grubhub.com/restaurant/pizaros-pizza-1000-west-gray-street-houston/2318200?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2318200',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53459348498e855d92019446-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6622caf964a520ae152be3',
#        'name': 'Russo New York Pizzeria',
#        'location': {'address': '306 Gray St',
#         'crossStreet': 'btwn Bagby & Baldwin St.',
#         'lat': 29.7520496,
#         'lng': -95.37721739999999,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.7520496,
#           'lng': -95.37721739999999}],
#         'distance': 2050,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['306 Gray St (btwn Bagby & Baldwin St.)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1537582',
#         'url': 'https://www.grubhub.com/restaurant/russos-306-gray-st-houston/1537582?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1537582',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '101917104'}},
#       'referralId': 'e-0-4b6622caf964a520ae152be3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ada75a8f964a520c32221e3',
#        'name': 'House of Blues',
#        'location': {'address': '1204 Caroline St',
#         'crossStreet': 'at Dallas St',
#         'lat': 29.75382168551953,
#         'lng': -95.36395307867377,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75382168551953,
#           'lng': -95.36395307867377}],
#         'distance': 764,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1204 Caroline St (at Dallas St)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e5931735',
#          'name': 'Music Venue',
#          'pluralName': 'Music Venues',
#          'shortName': 'Music Venue',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2179587',
#         'url': 'https://www.grubhub.com/restaurant/house-of-blues-houston-1204-caroline-street-houston/2179587?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2179587',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '39508193'}},
#       'referralId': 'e-0-4ada75a8f964a520c32221e3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56d9cd9a498ecfa01c866d16',
#        'name': "luisa's pasta",
#        'location': {'address': '1200 McKinney St',
#         'lat': 29.75490690852692,
#         'lng': -95.3623446917791,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75490690852692,
#           'lng': -95.3623446917791}],
#         'distance': 578,
#         'postalCode': '77010',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1200 McKinney St',
#          'Houston, TX 77010',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56d9cd9a498ecfa01c866d16-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53c01391498e992507ca3044',
#        'name': 'Andiamo',
#        'location': {'lat': 29.761163,
#         'lng': -95.361232,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.761163,
#           'lng': -95.361232},
#          {'label': 'entrance', 'lat': 29.761287, 'lng': -95.361203}],
#         'distance': 708,
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Houston, TX', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53c01391498e992507ca3044-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f42ccd5e4b0c5334de17a11',
#        'name': 'Quatro Bar & Restaurant',
#        'location': {'lat': 29.763022097691675,
#         'lng': -95.36229359342164,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.763022097691675,
#           'lng': -95.36229359342164}],
#         'distance': 934,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Houston, TX 77002', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f42ccd5e4b0c5334de17a11-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5fdaea8d5fab5950cc778563',
#        'name': 'Tiny Champions',
#        'location': {'address': '2617 McKinney St',
#         'lat': 29.748392,
#         'lng': -95.350438,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.748392,
#           'lng': -95.350438}],
#         'distance': 1056,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['2617 McKinney St',
#          'Houston, TX 77003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5fdaea8d5fab5950cc778563-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e4c6c4ebd413c4cc66944a9',
#        'name': "Vincent's",
#        'location': {'address': '2701 Dallas St',
#         'lat': 29.746788000000002,
#         'lng': -95.350815,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.746788000000002,
#           'lng': -95.350815},
#          {'label': 'entrance', 'lat': 29.746498, 'lng': -95.351035}],
#         'distance': 1191,
#         'postalCode': '77003',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['2701 Dallas St',
#          'Houston, TX 77003',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
# ...
#         'distance': 1260,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['540 Texas St (btw Bagby St and Smith St)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-41326e00f964a52084121fe3-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba9021bf964a5201a033ae3',
#        'name': "Russo's New York Pizzeria",
#        'location': {'address': '604 Polk St',
#         'lat': 29.7562452,
#         'lng': -95.3702946,
#         'labeledLatLngs': [{'label': 'entrance',
#           'lat': 29.756288,
#           'lng': -95.370407},
#          {'label': 'display', 'lat': 29.7562452, 'lng': -95.3702946}],
#         'distance': 1327,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['604 Polk St',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1300612',
#         'url': 'https://www.grubhub.com/restaurant/russos-new-york-pizzeria-604-polk-st-houston/1300612?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1300612',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '101917071'}},
#       'referralId': 'e-0-4ba9021bf964a5201a033ae3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d55a78cecdbee0008f42358',
#        'name': 'BOH Pasta & Pizza',
#        'location': {'address': '409 Travis St',
#         'lat': 29.761708,
#         'lng': -95.362176,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.761708,
#           'lng': -95.362176}],
#         'distance': 813,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['409 Travis St',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5d55a78cecdbee0008f42358-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b58a294f964a520bc6228e3',
#        'name': 'Panini',
#        'location': {'address': '700 Milam St',
#         'crossStreet': 'Tunnel Level',
#         'lat': 29.760233010250317,
#         'lng': -95.3658339519169,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.760233010250317,
#           'lng': -95.3658339519169}],
#         'distance': 999,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['700 Milam St (Tunnel Level)',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b58a294f964a520bc6228e3-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ac3fb4a3fcee86a41f27e05',
#        'name': 'Mia Bella Trattoria',
#        'location': {'address': '1201 Caroline Street',
#         'lat': 29.75359424,
#         'lng': -95.36441446,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75359424,
#           'lng': -95.36441446},
#          {'label': 'entrance', 'lat': 29.753704, 'lng': -95.363533}],
#         'distance': 815,
#         'postalCode': '77002',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1201 Caroline Street',
#          'Houston, TX 77002',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '487363795'}},
#       'referralId': 'e-0-5ac3fb4a3fcee86a41f27e05-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5994ba571c675b0934d73f14',
#        'name': "Luigi's Italian Food",
#        'location': {'address': '2515 Bagby St',
#         'lat': 29.749719619750977,
#         'lng': -95.37787628173828,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.749719619750977,
#           'lng': -95.37787628173828}],
#         'distance': 2184,
#         'postalCode': '77006',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['2515 Bagby St',
#          'Houston, TX 77006',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '513794933'}},
#       'referralId': 'e-0-5994ba571c675b0934d73f14-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b2a847cf964a520aaaa24e3',
#        'name': 'Little Napoli Italian Cuisine',
#        'location': {'address': '540 Texas St.',
#         'lat': 29.7621244,
#         'lng': -95.3668441,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.7621244,
#           'lng': -95.3668441},
#          {'label': 'entrance', 'lat': 29.762199, 'lng': -95.366674}],
#         'distance': 1189,
#         'postalCode': '77007',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['540 Texas St.',
#          'Houston, TX 77007',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b2a847cf964a520aaaa24e3-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbd49b6078095215b81da91',
#        'name': "Michaelangelo's",
#        'location': {'address': '307 Westheimer Rd',
#         'crossStreet': '@ taft',
#         'lat': 29.744397999999997,
#         'lng': -95.384978,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.744397999999997,
#           'lng': -95.384978}],
#         'distance': 3047,
#         'postalCode': '77006',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['307 Westheimer Rd (@ taft)',
#          'Houston, TX 77006',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbd49b6078095215b81da91-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dc3326cd4c0ad9c0f503018',
#        'name': 'La Casa de Frida',
#        'location': {'address': '4002 N Main St',
#         'crossStreet': 'Walton',
#         'lat': 29.793751,
#         'lng': -95.376489,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.793751,
#           'lng': -95.376489}],
#         'distance': 4596,
#         'postalCode': '77009',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['4002 N Main St (Walton)',
#          'Houston, TX 77009',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dc3326cd4c0ad9c0f503018-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5931ada289e4902eeaedce89',
#        'name': "Rocco's",
#        'location': {'address': '811 Collingsworth St',
#         'lat': 29.79333794395743,
#         'lng': -95.35925477743149,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.79333794395743,
#           'lng': -95.35925477743149}],
#         'distance': 4135,
#         'postalCode': '77009',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['811 Collingsworth St',
#          'Houston, TX 77009',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '661160',
#         'url': 'https://www.grubhub.com/restaurant/roccos-811-collingsworth-st-houston/661160?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=661160',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5931ada289e4902eeaedce89-41'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eeec441f9ab8c5a032cfec9',
#        'name': "Sinatra's",
#        'location': {'address': '1924 Calumet St',
#         'lat': 29.721321999999997,
#         'lng': -95.38067,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.721321999999997,
#           'lng': -95.38067}],
#         'distance': 4534,
#         'postalCode': '77004',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1924 Calumet St',
#          'Houston, TX 77004',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4eeec441f9ab8c5a032cfec9-42'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56f88b34498e0f74d83546fc',
#        'name': 'Coltivare Patio',
#        'location': {'lat': 29.781665,
#         'lng': -95.393679,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.781665,
#           'lng': -95.393679}],
#         'distance': 4567,
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['Houston, TX', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56f88b34498e0f74d83546fc-43'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '530bcfc8498eeef6590985b8',
#        'name': 'Piatto Ristorante',
#        'location': {'address': '1111 Studewood St Ste B',
#         'crossStreet': 'Key St.',
#         'lat': 29.791471481323242,
#         'lng': -95.38829040527344,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.791471481323242,
#           'lng': -95.38829040527344}],
#         'distance': 4976,
#         'postalCode': '77008',
#         'cc': 'US',
#         'city': 'Houston',
#         'state': 'TX',
#         'country': 'United States',
#         'formattedAddress': ['1111 Studewood St Ste B (Key St.)',
#          'Houston, TX 77008',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-530bcfc8498eeef6590985b8-44'}]}]}}

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues)

filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues = nearby_venues.loc[:, filtered_columns]

nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   app.launch_new_instance()
#               name          categories        lat        lng
# 0         Perbacco  Italian Restaurant  29.760257 -95.364773
# 1  Grotto Downtown  Italian Restaurant  29.753918 -95.357197
# 2          Quattro  Italian Restaurant  29.754122 -95.362469
# 3          Potente  Italian Restaurant  29.757238 -95.357447
# 4   Birraporetti's  Italian Restaurant  29.762462 -95.364670

# %%
print("{} venues were returned for {} by Foursquare".format(len(nearby_venues), neighborhood_name))
# Out:
# 45 venues were returned for Downtown by Foursquare

# %% [markdown]
# #### List of the venues will be generated

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=5000):
    
    venues_list=[]
    for name, Latitude, Longitude in zip(names, latitudes, longitudes):
        print(name)

        url = 'https://api.foursquare.com/v2/venues/explore?&client_id=GTB2I3BTPHA0LFVNR1PXABL4A4LICUJ1H1JU3HI1UWRIVDRM&client_secret=T3ECK55FTGRIWW0IQGCHEDUDWN2VXDSYWSLEK01CRT33KSSB&ll=29.756260000000054,-95.35655999999994&radius=5000&limit=100'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            Latitude, 
            Longitude, 
            radius, 
            LIMIT)
            
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['Latitude'], 
            v['venue']['location']['Longitude'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
print(nearby_venues.shape)
nearby_venues.head(10)
# Out:
# (45, 4)
#                         name          categories        lat        lng
# 0                   Perbacco  Italian Restaurant  29.760257 -95.364773
# 1            Grotto Downtown  Italian Restaurant  29.753918 -95.357197
# 2                    Quattro  Italian Restaurant  29.754122 -95.362469
# 3                    Potente  Italian Restaurant  29.757238 -95.357447
# 4             Birraporetti's  Italian Restaurant  29.762462 -95.364670
# 5                   Your Pie  Italian Restaurant  29.751770 -95.368600
# 6  Brooklyn Meatball Company  Italian Restaurant  29.757325 -95.365266
# 7             Mandola's Deli  Italian Restaurant  29.737454 -95.339587
# 8           Luigi's Pizzeria  Italian Restaurant  29.735450 -95.374640
# 9           Osso & Kristalla  Italian Restaurant  29.757451 -95.357903

# %% [markdown]
# ### A map will be created to have better visualization of the restaurants distrubtion around the City

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centered from the center of the city

# add a red circle marker to represent the Conrad Hotel
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(nearby_venues.lat, nearby_venues.lng, nearby_venues.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_0f30db5b31d440f992683490e5984950%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0f30db5b31d440f992683490e5984950%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_0f30db5b31d440f992683490e5984950%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_0f30db5b31d440f992683490e5984950%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B29.7589382%2C%20-95.3676974%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# # Results and Discussion

# %% [markdown]
# After analyzing the data and gathering the information, 45 venues were found that offer italian food in Houston center. This number is relativly low for a city similar to Houston and considering one of the most favored type of food "Italian".
# It was clear from spotting the resutarnt in the map that the west part of the center doesn't have many restuarnts apart from some restaurants that are spread further west.

# %% [markdown]
# # Conclustion

# %% [markdown]
# After analyizing the data, the selection of an Italian restarants seems to be a very good selection in Houston city.
# As clearly elstirated in the map, the wesern part of the center doesn't have italian restaurants. Thus, the proposal to the stackholders is to establish a restaurant in the wesern part near Sam Houston park.
